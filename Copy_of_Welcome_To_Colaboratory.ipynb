# %%
from pytube import YouTube
from google.colab import files
from IPython.display import Image
url = str(input("Youtube video url:- "))
yt = YouTube(url)
print(yt.title)
Image(yt.thumbnail_url, width=320, height=180)
video = yt.streams.filter(progressive=True, file_extension='mp4').order_by('resolution').desc().first().download()

files.download(video)
# Out:
# Youtube video url:- https://www.youtube.com/watch?v=NO79YC580Ko&list=RDMM&index=2
# 𝗚𝗿𝗮𝗻𝗱 𝗙𝗶𝗻𝗮𝗹𝗲 | Sayisha के Cute Act ने जीता सबका दिल | Superstar Singer Season 2
