# %%
pip install pytube
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pytube in /usr/local/lib/python3.9/dist-packages (12.1.2)

# %%
from pytube import YouTube
from google.colab import files
from IPython.display import Image
url = str(input("Youtube video url:- "))
yt = YouTube(url)
print(yt.title)
Image(yt.thumbnail_url, width=320, height=180)
video = yt.streams.filter(progressive=True, file_extension='mp4').order_by('resolution').desc().first().download()
files.download(video)
# Out:
# Youtube video url:- https://www.youtube.com/watch?v=OtgVlUh_-JQ&t=3s
# আগুন ছারা ছেয়েকা | Gopal Bhar | Double Gopal | Full Episode
